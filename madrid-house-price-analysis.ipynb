# %% [markdown]
# # **Dataset Overview**

# %% [markdown]
# <h3 style="-webkit-text-stroke-width:0px;border-width:0px;color:rgb(232, 234, 237);font-family:Inter, sans-serif;font-size:16px;font-style:normal;font-variant-alternates:inherit;font-variant-caps:normal;font-variant-east-asian:inherit;font-variant-emoji:inherit;font-variant-ligatures:normal;font-variant-numeric:inherit;font-variant-position:inherit;letter-spacing:normal;line-height:20px;margin:24px 0px 8px;orphans:2;padding:0px;text-align:start;text-decoration-color:initial;text-decoration-style:initial;text-decoration-thickness:initial;text-indent:0px;text-transform:none;vertical-align:baseline;white-space:normal;widows:2;word-spacing:0px;"><strong>Data Dictionary</strong></h3>
# <figure class="table">
#     <table style="-webkit-text-stroke-width:0px;border-collapse:separate;border-color:rgb(128, 134, 139);border-radius:8px;border-spacing:0px;border-style:solid;color:rgb(189, 193, 198);display:block;font-family:Inter, sans-serif;font-size:14px;font-style:normal;font-variant-alternates:inherit;font-variant-caps:normal;font-variant-east-asian:inherit;font-variant-emoji:inherit;font-variant-ligatures:normal;font-variant-numeric:inherit;font-variant-position:inherit;font-weight:400;letter-spacing:normal;margin:0px;max-width:fit-content;orphans:2;overflow-x:auto;padding:0px;table-layout:fixed;text-align:start;text-decoration-color:initial;text-decoration-style:initial;text-decoration-thickness:initial;text-transform:none;vertical-align:baseline;white-space:normal;widows:2;word-break:normal;word-spacing:0px;">
#         <thead style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:0px;vertical-align:baseline;">
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <th style="border-width:0px;color:rgb(189, 193, 198);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;line-height:24px;margin:0px;padding:16px;vertical-align:middle;"><strong>Variable Name</strong></th>
#                 <th style="border-width:0px;color:rgb(189, 193, 198);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;line-height:24px;margin:0px;padding:16px;vertical-align:middle;"><strong>Description</strong></th>
#             </tr>
#         </thead>
#         <tbody style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:0px;vertical-align:baseline;">
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">ID</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Identifier ID</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">title</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Title from listing</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">subtitle</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Neighborhood and city</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">sq_mt_built</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Square meter built</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">sq_mt_useful</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Square meter useful</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">n_rooms</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Number of rooms</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">n_bathrooms</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Number of bathrooms</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">sq_mt_allotment</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Square meter allotment</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">latitude, longitude</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Latitude, Longitude (Since portals hide the location mainly NAs)</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">raw_address</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Address</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">is_exact_address_hidden</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Boolean values</td>
#             </tr>
#             <tr style="border-width:0px;font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;height:52px;margin:0px;padding:0px;vertical-align:baseline;">
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">buy_price</td>
#                 <td style="border-bottom:0px initial initial;border-image:initial;border-left:0px initial initial;border-right:0px initial initial;border-top:1px solid rgb(128, 134, 139);color:rgb(232, 234, 237);font-family:inherit;font-size:14px;font-style:inherit;font-variant:inherit;font-weight:inherit;margin:0px;padding:16px;vertical-align:middle;">Target Value</td>
#             </tr>
#         </tbody>
#     </table>
# </figure>

# %% [markdown]
# # **Data Preprocessing**

# %%
# Import libariry
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns   

# Configure pandas display options for better readability
pd.options.display.float_format = '{:,.1f}'.format
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# Set seaborn style for visualizations
sns.set()

# %%
# Load the Madrid housing dataset
data = pd.read_csv('/kaggle/input/houses-madrid/houses_Madrid.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 58 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    21742 non-null  int64
#  1   id                            21742 non-null  int64
#  2   title                         21742 non-null  object
#  3   subtitle                      21742 non-null  object
#  4   sq_mt_built                   21616 non-null  float64
#  5   sq_mt_useful                  8228 non-null   float64
#  6   n_rooms                       21742 non-null  int64
#  7   n_bathrooms                   21726 non-null  float64
#  8   n_floors                      1437 non-null   float64
#  9   sq_mt_allotment               1432 non-null   float64
#  10  latitude                      0 non-null      float64
#  11  longitude                     0 non-null      float64
# ...

# %%
# Remove columns with all NaN values
data = data.dropna(axis= 1, how= 'all')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    21742 non-null  int64
#  1   id                            21742 non-null  int64
#  2   title                         21742 non-null  object
#  3   subtitle                      21742 non-null  object
#  4   sq_mt_built                   21616 non-null  float64
#  5   sq_mt_useful                  8228 non-null   float64
#  6   n_rooms                       21742 non-null  int64
#  7   n_bathrooms                   21726 non-null  float64
#  8   n_floors                      1437 non-null   float64
#  9   sq_mt_allotment               1432 non-null   float64
#  10  raw_address                   16277 non-null  object
#  11  is_exact_address_hidden       21742 non-null  bool
# ...

# %%
# check For duplicate rows
data.duplicated().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'subtitle', 'sq_mt_built', 'sq_mt_useful',
#        'n_rooms', 'n_bathrooms', 'n_floors', 'sq_mt_allotment', 'raw_address',
#        'is_exact_address_hidden', 'street_name', 'street_number', 'floor',
#        'is_floor_under', 'neighborhood_id', 'operation', 'rent_price',
#        'is_rent_price_known', 'buy_price', 'buy_price_by_area',
#        'is_buy_price_known', 'house_type_id', 'is_renewal_needed',
#        'is_new_development', 'built_year', 'has_central_heating',
#        'has_individual_heating', 'has_ac', 'has_fitted_wardrobes', 'has_lift',
#        'is_exterior', 'has_garden', 'has_pool', 'has_terrace', 'has_balcony',
#        'has_storage_room', 'is_accessible', 'has_green_zones',
#        'energy_certificate', 'has_parking', 'is_parking_included_in_price',
#        'parking_price', 'is_orientation_north', 'is_orientation_west',
#        'is_orientation_south', 'is_orientation_east'],
#       dtype='object')

# %%
# taking only needed columns
df = data[['id', 'subtitle', 'sq_mt_built', 'sq_mt_useful', 'n_rooms', 'n_bathrooms',
            'n_floors', 'sq_mt_allotment', 'rent_price', 'buy_price', 'buy_price_by_area','built_year', 'parking_price']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21742 non-null  int64
#  1   subtitle           21742 non-null  object
#  2   sq_mt_built        21616 non-null  float64
#  3   sq_mt_useful       8228 non-null   float64
#  4   n_rooms            21742 non-null  int64
#  5   n_bathrooms        21726 non-null  float64
#  6   n_floors           1437 non-null   float64
#  7   sq_mt_allotment    1432 non-null   float64
#  8   rent_price         21742 non-null  int64
#  9   buy_price          21742 non-null  int64
#  10  buy_price_by_area  21742 non-null  int64
#  11  built_year         10000 non-null  float64
#  12  parking_price      7719 non-null   float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 2.2+ MB

# %%
# Rename 'subtitle' column to 'city'
df = df.rename(columns= {'subtitle':'city' })

# %%
# Keep only essential columns with fewer missing values  
df = df[['id', 'city', 'sq_mt_built', 'n_rooms', 'n_bathrooms', 'rent_price', 'buy_price', 'buy_price_by_area']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21742 non-null  int64
#  1   city               21742 non-null  object
#  2   sq_mt_built        21616 non-null  float64
#  3   n_rooms            21742 non-null  int64
#  4   n_bathrooms        21726 non-null  float64
#  5   rent_price         21742 non-null  int64
#  6   buy_price          21742 non-null  int64
#  7   buy_price_by_area  21742 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.3+ MB

# %%
# Display summary statistics for the number of rooms
df.n_rooms.describe()
# Out:
# count   21,742.0
# mean         3.0
# std          1.5
# min          0.0
# 25%          2.0
# 50%          3.0
# 75%          4.0
# max         24.0
# Name: n_rooms, dtype: float64

# %%
# Remove rows where number of rooms is zero
df.drop(df.index[df.n_rooms == 0], axis= 0, inplace= True)

# %%
# Calculate mode of bathrooms column
df.n_bathrooms.mode()
# Out:
# 0   1.0
# Name: n_bathrooms, dtype: float64

# %%
# Fill NaN values in bathrooms column with mode (1) and replace 0 with 1
df.n_bathrooms.fillna(1, inplace= True)
df.n_bathrooms = df.n_bathrooms.replace(0,1)
# Out:
# /tmp/ipykernel_13/1795872801.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.n_bathrooms.fillna(1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21303 entries, 0 to 21741
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21303 non-null  int64
#  1   city               21303 non-null  object
#  2   sq_mt_built        21177 non-null  float64
#  3   n_rooms            21303 non-null  int64
#  4   n_bathrooms        21303 non-null  float64
#  5   rent_price         21303 non-null  int64
#  6   buy_price          21303 non-null  int64
#  7   buy_price_by_area  21303 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.5+ MB

# %%
# Convert n_bathrooms to integer type 
df.n_bathrooms = df.n_bathrooms.astype(int)

# %%
# Remove rows with missing sq_mt_built values
df.dropna(subset= 'sq_mt_built', inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21177 entries, 0 to 21741
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21177 non-null  int64
#  1   city               21177 non-null  object
#  2   sq_mt_built        21177 non-null  float64
#  3   n_rooms            21177 non-null  int64
#  4   n_bathrooms        21177 non-null  int64
#  5   rent_price         21177 non-null  int64
#  6   buy_price          21177 non-null  int64
#  7   buy_price_by_area  21177 non-null  int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 1.5+ MB

# %%
df.sample(10)
# Out:
#           id                     city  sq_mt_built  n_rooms  n_bathrooms  \
# 2104   19638      Almendrales, Madrid         56.0        2            1
# 5007   16735  Palomeras Bajas, Madrid         63.0        2            1
# 16136   5606    Puerta Bonita, Madrid        110.0        3            2
# 15254   6488      Prosperidad, Madrid         65.0        1            1
# 18798   2944          Palacio, Madrid         55.0        1            1
# 17161   4581      Carabanchel, Madrid        132.0        3            2
# 10442  11300    Pinar del Rey, Madrid         60.0        2            1
# 4354   17388          Adelfas, Madrid         99.0        3            2
# 9028   12714       Peñagrande, Madrid         52.0        1            1
# 8730   13012       Peñagrande, Madrid        372.0        5            4
#
#        rent_price  buy_price  buy_price_by_area
# 2104          725     145000               2589
# 5007          666     130000               2063
# ...

# %%
# Replace negative values in rent_price with zero 
for value in df.rent_price.values:
    if value < 0:
        df.rent_price = 0

# %%
# split column city to (district, city)
df['district'] = df.city.str.split(',', expand= True)[0]

# %%
df.head(10)
# Out:
#       id                   city  sq_mt_built  n_rooms  n_bathrooms  \
# 0  21742  San Cristóbal, Madrid         64.0        2            1
# 1  21741    Los Ángeles, Madrid         70.0        3            1
# 2  21740     San Andrés, Madrid         94.0        2            2
# 3  21739     San Andrés, Madrid         64.0        2            1
# 4  21738    Los Rosales, Madrid        108.0        2            2
# 5  21737     San Andrés, Madrid        126.0        4            2
# 6  21736     San Andrés, Madrid        120.0        5            2
# 7  21735     Villaverde, Madrid        125.0        3            2
# 8  21734     Villaverde, Madrid         84.0        3            2
# 9  21733    Los Rosales, Madrid         85.0        2            1
#
#    rent_price  buy_price  buy_price_by_area       district
# 0           0      85000               1328  San Cristóbal
# 1           0     129900               1856    Los Ángeles
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'sq_mt_built', 'n_rooms', 'n_bathrooms', 'rent_price',
#        'buy_price', 'buy_price_by_area', 'district'],
#       dtype='object')

# %%
# Reorder columns for clarity
df = df[['id', 'district', 'sq_mt_built', 'n_rooms', 'n_bathrooms', 'rent_price',
       'buy_price', 'buy_price_by_area']]
df.head()
# Out:
#       id       district  sq_mt_built  n_rooms  n_bathrooms  rent_price  \
# 0  21742  San Cristóbal         64.0        2            1           0
# 1  21741    Los Ángeles         70.0        3            1           0
# 2  21740     San Andrés         94.0        2            2           0
# 3  21739     San Andrés         64.0        2            1           0
# 4  21738    Los Rosales        108.0        2            2           0
#
#    buy_price  buy_price_by_area
# 0      85000               1328
# 1     129900               1856
# 2     144247               1535
# 3     109900               1717
# 4     260000               2407

# %%
data.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  21742              Piso en venta en calle de Godella, 64
# 1           1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2           2  21740               Piso en venta en calle del Talco, 68
# 3           3  21739               Piso en venta en calle Pedro Jiménez
# 4           4  21738  Piso en venta en carretera de Villaverde a Val...
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid         64.0          60.0        2          1.0
# 1    Los Ángeles, Madrid         70.0           NaN        3          1.0
# 2     San Andrés, Madrid         94.0          54.0        2          2.0
# 3     San Andrés, Madrid         64.0           NaN        2          1.0
# 4    Los Rosales, Madrid        108.0          90.0        2          2.0
#
#    n_floors  sq_mt_allotment                         raw_address  \
# ...

# %%
# house_type_id is_new_development
data.is_new_development.unique()
# Out:
# array([False, nan, True], dtype=object)

# %%
# Remove rent_price column as it's not used in further analysis
df.drop(columns= ['rent_price'], inplace= True)

# %%
data[['house_type_id', 'is_new_development']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   house_type_id       21351 non-null  object
#  1   is_new_development  20750 non-null  object
# dtypes: object(2)
# memory usage: 339.8+ KB

# %%
df.head()
# Out:
#       id       district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 0  21742  San Cristóbal         64.0        2            1      85000
# 1  21741    Los Ángeles         70.0        3            1     129900
# 2  21740     San Andrés         94.0        2            2     144247
# 3  21739     San Andrés         64.0        2            1     109900
# 4  21738    Los Rosales        108.0        2            2     260000
#
#    buy_price_by_area
# 0               1328
# 1               1856
# 2               1535
# 3               1717
# 4               2407

# %%
df.id = df.id.astype('object')

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## **Distribution of Numerical Features**

# %%
# distribution of numerical features
plt.figure(figsize=(12,6))
for e,i in enumerate (df.columns[3:]):
    plt.subplot(2, 2, e+1)
    sns.histplot(df[i], kde= True)
    plt.title('distribution'  +i);
    plt.tight_layout();
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## **Outlier Detection**

# %%
# outliers in numerical features
plt.figure(figsize=(20, 10))
for e,i in enumerate (df.columns[3:]):
    plt.subplot(2, 3, e+1)
    sns.boxenplot(x= df[i])
    plt.title('distribution'  +i);
    plt.tight_layout();
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Display count of properties by district
df.district.value_counts()
# Out:
# district
# Chamartín                           840
# Moncloa                             692
# Chamberí                            576
# Centro                              541
# Hortaleza                           482
# Barrio de Salamanca                 457
# Fuencarral                          371
# Malasaña-Universidad                327
# Lavapiés-Embajadores                310
# Tetuán                              292
# Ensanche de Vallecas - La Gavia     288
# Prosperidad                         284
# Pueblo Nuevo                        277
# Ciudad Lineal                       274
# El Cañaveral - Los Berrocales       266
# San Diego                           261
# Argüelles                           253
# San Isidro                          248
# Retiro                              238
# Cuatro Caminos                      231
# Ventas                              228
# San Andrés                          217
# Peñagrande                          215
# ...

# %% [markdown]
# ## **correlation coeffcient**

# %%
# Create pairplot to analyze relationships between numerical features
corr = df[['sq_mt_built', 'n_rooms', 'n_bathrooms']]

sns.pairplot(corr, kind= 'reg')
plt.tight_layout();
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot regression line to show correlation between area and buy price
sns.regplot(data= df, x= 'sq_mt_built', y= 'buy_price')
plt.title('corelation between area (n2) and buyprice')
plt.xlabel('area (n2)')
plt.ylabel('buy price')
# Out:
# Text(0, 0.5, 'buy price')

# %%
# Display heatmap of correlation coefficients for numerical features
sns.heatmap(corr.corr(), annot= True)
plt.title('Correlation Coefficient Between Numerical Columns')
# Out:
# Text(0.5, 1.0, 'Correlation Coefficient Between Numerical Columns')

# %%
# Display heatmap of correlation between buy price and property features
corr = df[['buy_price','sq_mt_built', 'n_rooms', 'n_bathrooms']]
sns.heatmap(corr.corr(), annot= True);

# %%
df.head()
# Out:
#       id       district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 0  21742  San Cristóbal         64.0        2            1      85000
# 1  21741    Los Ángeles         70.0        3            1     129900
# 2  21740     San Andrés         94.0        2            2     144247
# 3  21739     San Andrés         64.0        2            1     109900
# 4  21738    Los Rosales        108.0        2            2     260000
#
#    buy_price_by_area
# 0               1328
# 1               1856
# 2               1535
# 3               1717
# 4               2407

# %% [markdown]
# ### **Location or Size: What Influences House Prices in Madrid?**
#
# ### **Do Housing Prices Vary by District? If So, Which Are the Most Expensive Areas for Purchasing a Home?**

# %%
# Calculate and plot mean buy price by district
mean_price = df.groupby(['district'])['buy_price'].mean().round(2).sort_values(ascending= True)
mean_price.head(10).plot(kind= 'bar', xlabel= 'district', ylabel= 'buy price', title= 'mean price by district')
# Out:
# <Axes: title={'center': 'mean price by district'}, xlabel='district', ylabel='buy price'>

# %%
# Calculate and plot mean buy price per square meter by district
mean_price = df.groupby(['district'])['buy_price_by_area'].mean().round(2).sort_values(ascending= True)
mean_price.head(10).plot(kind= 'bar', xlabel= 'district', ylabel= 'buy price area')
# Out:
# <Axes: xlabel='district', ylabel='buy price area'>

# %% [markdown]
# # **Modeling**

# %% [markdown]
# ## **linear regression model**

# %%
# Filter data for Recoletos district
reco = df.query('district == "Recoletos"')

# %%
reco.sample(10)
# Out:
#          id   district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 19619  2123  Recoletos        365.0        5            5    3276000
# 19120  2622  Recoletos        127.0        2            2     990000
# 19419  2323  Recoletos        270.0        4            2    1970000
# 20140  1602  Recoletos        185.0        3            3    1750000
# 19503  2239  Recoletos        390.0        5            4    2290000
# 20136  1606  Recoletos        404.0        5            6    4350000
# 19741  2001  Recoletos        274.0        4            3    3200000
# 20061  1681  Recoletos        247.0        4            2    1700000
# 19823  1919  Recoletos        134.0        1            1     750000
# 19623  2119  Recoletos        644.0        5            3    4900000
#
#        buy_price_by_area
# 19619               8975
# 19120               7795
# 19419               7296
# 20140               9459
# 19503               5872
# 20136              10767
# ...

# %%
# Fit linear regression model for Recoletos district
import statsmodels.api as sm

reco['intercept'] = 1
linear_model = sm.OLS(reco['buy_price'], reco[['intercept', 'sq_mt_built']])
result = linear_model.fit()
result.summary()
# Out:
# /tmp/ipykernel_13/1183645247.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reco['intercept'] = 1
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     555.1
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           5.30e-45
# Time:                        15:45:58   Log-Likelihood:                -1654.1
# No. Observations:                 113   AIC:                             3312.
# ...

# %%
# Predict price for a 300 m² flat in Recoletos
# yhat = b0 + b1 * x

x= 300
price = 152500+6348 * x
print("predicted price of flat in recoletos with are of {} m2 = {} euro".format(x, price))
# Out:
# predicted price of flat in recoletos with are of 300 m2 = 2056900 euro

# %% [markdown]
# ## **multilinear regression model**

# %%
reco.head()
# Out:
#          id   district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 19102  2640  Recoletos        114.0        4            1     750000
# 19106  2636  Recoletos        250.0        3            4    2990000
# 19110  2632  Recoletos        187.0        3            3    1450000
# 19117  2625  Recoletos        417.0        7            6    2500000
# 19120  2622  Recoletos        127.0        2            2     990000
#
#        buy_price_by_area  intercept
# 19102               6579          1
# 19106              11960          1
# 19110               7754          1
# 19117               5995          1
# 19120               7795          1

# %%
# Display heatmap of correlations for Recoletos district
corr = reco[['buy_price', 'sq_mt_built', 'n_rooms', 'n_bathrooms']]
sns.heatmap(corr.corr(), annot= True)
plt.title('correlation coeffcinet between numrical columns');

# %%
# Fit multilinear regression model for Recoletos district
lm = sm.OLS(reco.buy_price, reco[['intercept', 'sq_mt_built', 'n_rooms', 'n_bathrooms']])
result = lm.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     245.2
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           2.69e-48
# Time:                        15:45:59   Log-Likelihood:                -1639.7
# No. Observations:                 113   AIC:                             3287.
# Df Residuals:                     109   BIC:                             3298.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# intercept    1.068e+05   1.29e+05      0.828      0.409   -1.49e+05    3.62e+05
# ...

# %%
# Predict price for a 300 m² flat with 3 bathrooms in Recoletos
area = 300
bath = 3
price = 121200 + 3895.9 * area + 196000 * bath

print('predicted price of flat in recoletos with area of {} m2 and {} bathroom = {} Eure'.format(area, bath, price))
# Out:
# predicted price of flat in recoletos with area of 300 m2 and 3 bathroom = 1877970.0 Eure

# %%
# Fit multilinear regression model for Recoletos district
lm = sm.OLS(reco.buy_price, reco[['intercept', 'n_rooms', 'n_bathrooms']])
result = lm.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.584
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     77.32
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           1.07e-21
# Time:                        15:45:59   Log-Likelihood:                -1705.8
# No. Observations:                 113   AIC:                             3418.
# Df Residuals:                     110   BIC:                             3426.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# intercept   -3.288e+05   2.25e+05     -1.462      0.147   -7.74e+05    1.17e+05
# ...

# %% [markdown]
# ## **Regression with Dummy Variables for Selected Districts**

# %%
# Display number of unique districts
df.district.nunique()
# Out:
# 146

# %%
# Display unique district names
df.district.unique()
# Out:
# array(['San Cristóbal', 'Los Ángeles', 'San Andrés', 'Los Rosales',
#        'Villaverde', 'Butarque', 'Vicálvaro', 'Ambroz',
#        'Casco Histórico de Vicálvaro', 'El Cañaveral - Los Berrocales',
#        'Valdebernardo - Valderribas', 'Casco Histórico de Vallecas',
#        'Ensanche de Vallecas - La Gavia', 'Villa de Vallecas',
#        'Santa Eugenia', 'Orcasitas', 'Usera', 'San Fermín', 'Pradolongo',
#        'Zofío', 'Almendrales', 'Moscardó', '12 de Octubre-Orcasur',
#        'Valdeacederas', 'Tetuán', 'Berruguete', 'Cuatro Caminos',
#        'Cuzco-Castillejos', 'Bellas Vistas', 'Ventilla-Almenara',
#        'Retiro', 'Adelfas', 'Ibiza', 'Pacífico', 'Niño Jesús',
#        'Jerónimos', 'Estrella', 'Puente de Vallecas', 'Palomeras Bajas',
#        'San Diego', 'Palomeras sureste', 'Entrevías', 'Numancia',
#        'Portazgo', 'Aravaca', 'Argüelles', 'Moncloa',
#        'Ciudad Universitaria', 'Valdezarza', 'Fontarrón', 'Moratalaz',
# ...

# %%
# Filter data for specific districts (Recoletos, Castellana, Trafalgar)
df_dummy = df.query("district in ( 'Recoletos', 'Castellana', 'Trafalgar')")
df_dummy.head()
# Out:
#           id   district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 10937  10805  Trafalgar         68.0        2            1     510000
# 11000  10742  Trafalgar        103.0        2            2     980000
# 11001  10741  Trafalgar        103.0        2            2     960000
# 11010  10732  Trafalgar         95.0        4            1     239000
# 11042  10700  Trafalgar         67.0        2            2     550000
#
#        buy_price_by_area
# 10937               7500
# 11000               9515
# 11001               9320
# 11010               2516
# 11042               8209

# %%
pd.get_dummies(df_dummy.district).head()
# Out:
#        Castellana  Recoletos  Trafalgar
# 10937       False      False       True
# 11000       False      False       True
# 11001       False      False       True
# 11010       False      False       True
# 11042       False      False       True

# %%
# Create dummy variables for districts
df_dummy[['cast', 'reco', 'traf']] = pd.get_dummies(df_dummy['district'], dtype= 'int')
df_dummy.head()
# Out:
# /tmp/ipykernel_13/4165463172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dummy[['cast', 'reco', 'traf']] = pd.get_dummies(df_dummy['district'], dtype= 'int')
# /tmp/ipykernel_13/4165463172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dummy[['cast', 'reco', 'traf']] = pd.get_dummies(df_dummy['district'], dtype= 'int')
# /tmp/ipykernel_13/4165463172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Fit regression model with dummy variables
df_dummy['entercept'] = 1

lm = sm.OLS(df_dummy.buy_price, df_dummy[['entercept', 'cast', 'traf']])
result = lm.fit()
result.summary()
# Out:
# /tmp/ipykernel_13/53744632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dummy['entercept'] = 1
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                     114.3
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           5.20e-40
# Time:                        15:45:59   Log-Likelihood:                -6095.1
# No. Observations:                 404   AIC:                         1.220e+04
# ...

# %%
# Fit regression model with dummy variables and area
df_dummy['entercept'] = 1

lm = sm.OLS(df_dummy.buy_price, df_dummy[['entercept', 'cast', 'traf', 'sq_mt_built']])
result = lm.fit()
result.summary()
# Out:
# /tmp/ipykernel_13/4085285004.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dummy['entercept'] = 1
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     859.3
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):          6.30e-174
# Time:                        15:45:59   Log-Likelihood:                -5780.8
# No. Observations:                 404   AIC:                         1.157e+04
# ...
